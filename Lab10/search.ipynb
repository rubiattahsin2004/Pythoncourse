# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
value = 30
position = np.where(arr == value)

# %%
print("Array:", arr)
print("Position of", value, ":", position)
# Out:
# Array: [10 20 30 40 50]
# Position of 30 : (array([2]),)
