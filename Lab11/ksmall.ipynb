# %%
import numpy as np

# %%
arr = np.array([10, 3, 7, 1, 8, 2, 5])

# %%
k = 3

# %%
smallest = np.sort(arr)[:k]

# %%
print("K-smallest values:")
print(smallest)
# Out:
# K-smallest values:
# [1 2 3]
