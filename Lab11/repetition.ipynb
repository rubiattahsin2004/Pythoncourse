# %%
import numpy as np

# %%
arr = np.array([10, 20, 10, 30, 10, 40, 10])

# %%
value = 10

# %%
n = 3

# %%
positions = np.where(arr == value)[0]

# %%
index = positions[n - 1]

# %%
print("Index of the", n, "rd repetition:", index)
# Out:
# Index of the 3 rd repetition: 4
